# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# sns - загально прийнятий псевдонім для seaborn

# %%
# вимикаємо зайві попередження
import warnings

warnings.filterwarnings("ignore")

# %%
tips = sns.load_dataset("tips")

tips

# використаємо один з датасетів що йдуть в комплекті з seaborn
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.style.use('seaborn-v0_8')

plt.scatter(tips['total_bill'], tips['tip'])
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Total Bill vs Tip')
plt.show()

# створимо простий scatter plot використовуючи matplotlib

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips);

# %%
sns.relplot(x='total_bill', 
            y='tip', 
            data=tips, 
            
            col = 'time',  # розбиваємо на два графіки по time
            hue = 'smoker', # розбиваємо на два графіки по smoker
            style = 'smoker',
            size = 'size');

# %%
# relplot - це функція для створення графіків в seaborn 
# вона є вищорівневою і може викликати інші функції seaborn
# вона приймає аргументи x, y, data, col, hue, style, size

sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    col="time",  # розбиваємо на два графіки по time
    #hue="smoker",  # розбиваємо на два графіки по smoker
    #style="smoker",
    #size="size",
)

# Точкова діаграма "на макималках"

# %%
sns.lmplot(x='total_bill', y='tip', data=tips);

# в seaborn є функція lmplot яка створює лінійну модель

# %%
sns.displot(tips['total_bill'], bins=30);

# Гістограма в seaborn

# %%
sns.displot(tips["total_bill"], bins=30)
plt.title("Histogram of Total Bill")
plt.xlabel("Total Bill")
plt.ylabel("Frequency")
plt.show();

# функкції з matplotlib працюють для seaborn

# %%
sns.displot(data = tips, x = 'total_bill', col = 'time');

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow');
# 

# boxplot - це ящик з вусами``

# %%
sns.catplot(x="day", y="total_bill", data=tips, palette='rainbow' , kind="violin");

# %%
# відбираю числові ознаки з датасету tips
df = tips.select_dtypes(include=['float64', 'int64'])

# %%
df
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# heatmap - це теплова карта
sns.heatmap(df.corr(), cmap="crest_r", annot=True)
# Out:
# <Axes: >

# %%
# heatmap - це теплова карта
sns.heatmap(df.corr(), cmap="crest_r", annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 3))  # figsize - розмір фігури

sns.barplot(
    x="total_bill",
    y="tip",
    data=tips[0:300],
)
plt.title("Barplot of Total Bill vs Tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.xticks(rotation=90)
plt.xticks(np.arange(0, 300, 7))  # вивести кожен 7-ий підпис по осі x
plt.show()

# %%
# Припустимо, у вас є серія дат
date_series = pd.date_range(start="2024-01-01", end="2024-12-31", freq="D")

# date_series = df['date_col'].unique()

# Вибрати кожен сьомий елемент
every_seventh_day = date_series[::7]

print(every_seventh_day)
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-08', '2024-01-15', '2024-01-22',
#                '2024-01-29', '2024-02-05', '2024-02-12', '2024-02-19',
#                '2024-02-26', '2024-03-04', '2024-03-11', '2024-03-18',
#                '2024-03-25', '2024-04-01', '2024-04-08', '2024-04-15',
#                '2024-04-22', '2024-04-29', '2024-05-06', '2024-05-13',
#                '2024-05-20', '2024-05-27', '2024-06-03', '2024-06-10',
#                '2024-06-17', '2024-06-24', '2024-07-01', '2024-07-08',
#                '2024-07-15', '2024-07-22', '2024-07-29', '2024-08-05',
#                '2024-08-12', '2024-08-19', '2024-08-26', '2024-09-02',
#                '2024-09-09', '2024-09-16', '2024-09-23', '2024-09-30',
#                '2024-10-07', '2024-10-14', '2024-10-21', '2024-10-28',
#                '2024-11-04', '2024-11-11', '2024-11-18', '2024-11-25',
#                '2024-12-02', '2024-12-09', '2024-12-16', '2024-12-23',
#                '2024-12-30'],
#               dtype='datetime64[ns]', freq='7D')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Створення прикладу DataFrame з PeriodIndex
df = pd.DataFrame(
    {"date": pd.period_range("2024-01", periods=12, freq="M"), "value": range(12)}
)

plt.plot(df["date"], df["value"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 9
#       4 # Створення прикладу DataFrame з PeriodIndex
#       5 df = pd.DataFrame(
#       6     {"date": pd.period_range("2024-01", periods=12, freq="M"), "value": range(12)}
#       7 )
# ----> 9 plt.plot(df["date"], df["value"])
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1723, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
# -> 1723     self.add_line(line)
#    1724 if scalex:
#    1725     self._request_autoscale_view("x")
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/axes/_base.py:2309, in _AxesBase.add_line(self, line)
#    2306 if line.get_clip_path() is None:
#    2307     line.set_clip_path(self.patch)
# -> 2309 self._update_line_limits(line)
#    2310 if not line.get_label():
#    2311     line.set_label(f'_child{len(self._children)}')
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/axes/_base.py:2332, in _AxesBase._update_line_limits(self, line)
#    2328 def _update_line_limits(self, line):
#    2329     """
#    2330     Figures out the data limit of the given line, updating self.dataLim.
#    2331     """
# -> 2332     path = line.get_path()
#    2333     if path.vertices.size == 0:
#    2334         return
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/lines.py:1032, in Line2D.get_path(self)
#    1030 """Return the `~matplotlib.path.Path` associated with this line."""
#    1031 if self._invalidy or self._invalidx:
# -> 1032     self.recache()
#    1033 return self._path
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/lines.py:669, in Line2D.recache(self, always)
#     667 if always or self._invalidx:
#     668     xconv = self.convert_xunits(self._xorig)
# --> 669     x = _to_unmasked_float_array(xconv).ravel()
#     670 else:
#     671     x = self._x
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/cbook.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a real number, not 'Period'

# %%
# Перетворення Period на Timestamp
df["date"] = df["date"].dt.to_timestamp()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    12 non-null     datetime64[ns]
#  1   value   12 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 320.0 bytes

# %%
# Створення графіку
plt.plot(df["date"], df["value"])
plt.show()
